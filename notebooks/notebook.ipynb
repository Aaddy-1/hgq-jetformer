# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

import keras
print(f"Using Backend: {keras.backend.backend()}") 
# Should output: 'jax'
# Out:
# Using Backend: jax

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"
import keras
import keras.ops as ops
import jax.numpy as jnp

# Test a basic operation
x = ops.ones((2, 5))
y = ops.matmul(x, ops.transpose(x))

print(f"Tensor Type: {type(y)}")
# Verification: Should be <class 'jaxlib.xla_extension.ArrayImpl'> or similar JAX type
# Out:
# Tensor Type: <class 'jaxlib._jax.ArrayImpl'>
